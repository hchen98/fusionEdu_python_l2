# %% [markdown]
# Q: when we have an error in our program, what will happen?
#
# <br><br><br>
#
#
#
# ---
#
#
#
# There may by two types of erros in Python: syntax errors and Exceptions.
#
# ![image.png](data:image/png;base64,...)
#
#
# <br>
# Syntax error:
#
# We have `prinr("Hooray")` instead of `print("Hooray!")`

# %%
prinr("Hooray")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8ed38b601e9e> in <module>
# ----> 1 prinr("Hooray")
#
# NameError: name 'prinr' is not defined

# %%
print("Hooray!")
# Out:
# Hooray!

# %% [markdown]
# Exceptions
#
# **Formal definition**: when teh program is syntactically correct, but the code resulted in an error. This error does not stop the execution of the program, however, it changes the normal flow of the program.
#
# **Informal definition**: there is a logical error in your code.

# %%
score = 100 / 0

print(score)

# %% [markdown]
# ---
#
#
#
# ---

# %%
score = 100 / 0

print(score)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-5-d29da883e7ae> in <module>
# ----> 1 score = 100 / 0
#       2
#       3 print(score)
#
# ZeroDivisionError: division by zero

# %%
mylist = ["i", "j", "k"]

print(mylist[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-81a5b8388ff8> in <module>
#       1 mylist = ["i", "j", "k"]
#       2
# ----> 3 print(mylist[3])
#
# IndexError: list index out of range
